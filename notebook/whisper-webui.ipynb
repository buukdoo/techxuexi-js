# %% [markdown]
# ---
#
# 📌 **This notebook has been updated [here](https://github.com/jhj0517/Whisper-WebUI.git)!**
#
# 🖋 **Author**: [jhj0517](https://github.com/jhj0517/Whisper-WebUI/blob/master/notebook/whisper-webui.ipynb)
#
# 😎 **Support the Project**:
#
# If you find this project useful, please consider supporting it:
#
# ❤️ https://github.com/sponsors/jhj0517
#
# ---

# %%
#@title #(Optional) Check GPU
#@markdown Some models may not function correctly on a CPU runtime.

#@markdown so you should check your GPU setup before run.
# !nvidia-smi
# Out:
# Thu Jan 22 17:47:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#@title #Installation
#@markdown This cell will install dependencies for Whisper-WebUI!
# !git clone https://github.com/jhj0517/Whisper-WebUI.git
# %cd Whisper-WebUI
# !pip install git+https://github.com/jhj0517/jhj0517-whisper.git
# !pip install faster-whisper==1.1.1
# !pip install gradio==5.29.0
# !pip install gradio-i18n==0.3.1
# Temporal bug fix from https://github.com/jhj0517/Whisper-WebUI/issues/256
# !pip install git+https://github.com/JuanBindez/pytubefix.git
# !pip install pyannote.audio==3.3.1
# !pip install git+https://github.com/jhj0517/ultimatevocalremover_api.git
# !pip install git+https://github.com/jhj0517/gradio-i18n.git

# Lock down torch audio : https://github.com/jhj0517/Whisper-WebUI/issues/606
# !pip install torch==2.8.0 torchvision==0.23.0 torchaudio==2.8.0 --index-url https://download.pytorch.org/whl/cu126
# Out:
# fatal: destination path 'Whisper-WebUI' already exists and is not an empty directory.
# /content/Whisper-WebUI
# Collecting git+https://github.com/jhj0517/jhj0517-whisper.git
#   Cloning https://github.com/jhj0517/jhj0517-whisper.git to /tmp/pip-req-build-oay_hwdl
#   Running command git clone --filter=blob:none --quiet https://github.com/jhj0517/jhj0517-whisper.git /tmp/pip-req-build-oay_hwdl
#   Resolved https://github.com/jhj0517/jhj0517-whisper.git to commit 197244318d5d75d9d195bff0705ab05a591684ec
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20240930) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20240930) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20240930) (2.9.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20240930) (4.67.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20240930) (10.8.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20240930) (0.12.0)
# Requirement already satisfied: triton>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20240930) (3.5.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper==20240930) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper==20240930) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper==20240930) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20240930) (1.11.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper==20240930) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->openai-whisper==20240930) (3.0.3)
# Requirement already satisfied: faster-whisper==1.1.1 in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.1.1) (4.6.3)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.1.1) (0.36.0)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.1.1) (0.22.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.1.1) (1.23.2)
# Requirement already satisfied: av>=11 in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.1.1) (16.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.1.1) (4.67.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper==1.1.1) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper==1.1.1) (2.0.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper==1.1.1) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1) (1.2.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper==1.1.1) (10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper==1.1.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper==1.1.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper==1.1.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper==1.1.1) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper==1.1.1) (1.3.0)
# Requirement already satisfied: gradio==5.29.0 in /usr/local/lib/python3.12/dist-packages (5.29.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (4.12.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.123.10)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (1.0.0)
# Requirement already satisfied: gradio-client==1.10.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (1.10.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (3.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (2.3.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (2.11.10)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.0.21)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.14.13)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.21.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.29.0) (0.40.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.10.0->gradio==5.29.0) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.10.0->gradio==5.29.0) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio==5.29.0) (3.11)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==5.29.0) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==5.29.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==5.29.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==5.29.0) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio==5.29.0) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio==5.29.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio==5.29.0) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio==5.29.0) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.29.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.29.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.29.0) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio==5.29.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio==5.29.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio==5.29.0) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.29.0) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.29.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.29.0) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio==5.29.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.29.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.29.0) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.28.1->gradio==5.29.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.28.1->gradio==5.29.0) (2.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==5.29.0) (0.1.2)
# Requirement already satisfied: gradio-i18n==0.3.1 in /usr/local/lib/python3.12/dist-packages (0.3.1)
# Requirement already satisfied: gradio>=4.32 in /usr/local/lib/python3.12/dist-packages (from gradio-i18n==0.3.1) (5.29.0)
# Requirement already satisfied: langcodes<3.5 in /usr/local/lib/python3.12/dist-packages (from gradio-i18n==0.3.1) (3.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from gradio-i18n==0.3.1) (6.0.3)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (4.12.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.123.10)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (1.0.0)
# Requirement already satisfied: gradio-client==1.10.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (1.10.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (3.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (2.3.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (2.11.10)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.0.21)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.14.13)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.21.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.40.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.10.0->gradio>=4.32->gradio-i18n==0.3.1) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.10.0->gradio>=4.32->gradio-i18n==0.3.1) (15.0.1)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<3.5->gradio-i18n==0.3.1) (1.4.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio>=4.32->gradio-i18n==0.3.1) (3.11)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio>=4.32->gradio-i18n==0.3.1) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio>=4.32->gradio-i18n==0.3.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio>=4.32->gradio-i18n==0.3.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=4.32->gradio-i18n==0.3.1) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (1.2.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<3.5->gradio-i18n==0.3.1) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.32->gradio-i18n==0.3.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.32->gradio-i18n==0.3.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.32->gradio-i18n==0.3.1) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio>=4.32->gradio-i18n==0.3.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio>=4.32->gradio-i18n==0.3.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio>=4.32->gradio-i18n==0.3.1) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio>=4.32->gradio-i18n==0.3.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (2.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (0.1.2)
# Collecting git+https://github.com/JuanBindez/pytubefix.git
#   Cloning https://github.com/JuanBindez/pytubefix.git to /tmp/pip-req-build-lttc2pag
#   Running command git clone --filter=blob:none --quiet https://github.com/JuanBindez/pytubefix.git /tmp/pip-req-build-lttc2pag
#   Resolved https://github.com/JuanBindez/pytubefix.git to commit 1923d73ddbdbb75a1947ccdf874b0211050a4401
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp>=3.12.13 in /usr/local/lib/python3.12/dist-packages (from pytubefix==10.3.6) (3.13.3)
# Requirement already satisfied: nodejs-wheel-binaries>=22.20.0 in /usr/local/lib/python3.12/dist-packages (from pytubefix==10.3.6) (24.13.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix==10.3.6) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix==10.3.6) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix==10.3.6) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix==10.3.6) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix==10.3.6) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix==10.3.6) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix==10.3.6) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.12.13->pytubefix==10.3.6) (4.15.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.12.13->pytubefix==10.3.6) (3.11)
# Requirement already satisfied: pyannote.audio==3.3.1 in /usr/local/lib/python3.12/dist-packages (3.3.1)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (0.8.1)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (0.36.0)
# Requirement already satisfied: lightning>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (2.6.0)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (2.3.0)
# Requirement already satisfied: pyannote.core>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (6.0.1)
# Requirement already satisfied: pyannote.database>=5.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (6.1.1)
# Requirement already satisfied: pyannote.metrics>=3.2 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (4.0.0)
# Requirement already satisfied: pyannote.pipeline>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (4.0.0)
# Requirement already satisfied: pytorch-metric-learning>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (2.9.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (13.9.4)
# Requirement already satisfied: semver>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (3.0.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (0.13.1)
# Requirement already satisfied: speechbrain>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (1.0.3)
# Requirement already satisfied: tensorboardX>=2.6 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (2.6.4)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (2.9.0+cu126)
# Requirement already satisfied: torch-audiomentations>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (0.12.0)
# Requirement already satisfied: torchaudio>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (2.9.0+cu126)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.3.1) (1.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio==3.3.1) (2.0.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio==3.3.1) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (1.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.1->pyannote.audio==3.3.1) (0.15.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.1->pyannote.audio==3.3.1) (2.6.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf<3.0,>=2.1->pyannote.audio==3.3.1) (4.9.3)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from pyannote.core>=5.0.0->pyannote.audio==3.3.1) (2.3.3)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.core>=5.0.0->pyannote.audio==3.3.1) (2.4.0)
# Collecting numpy (from asteroid-filterbanks>=0.4->pyannote.audio==3.3.1)
#   Using cached numpy-2.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==3.3.1) (1.6.1)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==3.3.1) (1.16.3)
# Requirement already satisfied: optuna>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.pipeline>=3.0.1->pyannote.audio==3.3.1) (4.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->pyannote.audio==3.3.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->pyannote.audio==3.3.1) (2.19.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->pyannote.audio==3.3.1) (2.0.0)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.12/dist-packages (from speechbrain>=1.0.0->pyannote.audio==3.3.1) (1.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from speechbrain>=1.0.0->pyannote.audio==3.3.1) (1.5.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from speechbrain>=1.0.0->pyannote.audio==3.3.1) (0.2.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX>=2.6->pyannote.audio==3.3.1) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.3.1) (3.5.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio==3.3.1) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio==3.3.1) (1.2.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio==3.3.1) (2.23)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.3.1) (3.13.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio==3.3.1) (0.1.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.3.1) (1.18.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.3.1) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.3.1) (2.0.45)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->pyannote.core>=5.0.0->pyannote.audio==3.3.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->pyannote.core>=5.0.0->pyannote.audio==3.3.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->pyannote.core>=5.0.0->pyannote.audio==3.3.1) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->pyannote.metrics>=3.2->pyannote.audio==3.3.1) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->pyannote.audio==3.3.1) (1.3.0)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.12/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio==3.3.1) (1.3)
# Requirement already satisfied: ruamel.yaml<0.19.0,>=0.17.28 in /usr/local/lib/python3.12/dist-packages (from hyperpyyaml->speechbrain>=1.0.0->pyannote.audio==3.3.1) (0.18.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->pyannote.audio==3.3.1) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio==3.3.1) (2026.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.3.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.3.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.3.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.3.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.3.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.3.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.3.1) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.3.1) (1.3.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->pyannote.core>=5.0.0->pyannote.audio==3.3.1) (1.17.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml<0.19.0,>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote.audio==3.3.1) (0.2.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.3.1) (3.3.0)
# Using cached numpy-2.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.1 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.1 which is incompatible.
# Successfully installed numpy-2.4.1
# Collecting git+https://github.com/jhj0517/ultimatevocalremover_api.git
#   Cloning https://github.com/jhj0517/ultimatevocalremover_api.git to /tmp/pip-req-build-7dwtl_vd
#   Running command git clone --filter=blob:none --quiet https://github.com/jhj0517/ultimatevocalremover_api.git /tmp/pip-req-build-7dwtl_vd
#   Resolved https://github.com/jhj0517/ultimatevocalremover_api.git to commit 3543be1349ce601568787b69cca0c1f8acba7c2e
#   Preparing metadata (setup.py) ... done
# Collecting dora-search>=0.1.12 (from uvr==0.1)
#   Using cached dora_search-0.1.12-py3-none-any.whl
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from uvr==0.1) (0.8.1)
# Collecting flake8 (from uvr==0.1)
#   Using cached flake8-7.3.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting hydra-colorlog>=1.1 (from uvr==0.1)
#   Using cached hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# Collecting hydra-core>=1.1 (from uvr==0.1)
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: julius>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from uvr==0.1) (0.2.7)
# Collecting lameenc>=1.2 (from uvr==0.1)
#   Using cached lameenc-1.8.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (9.9 kB)
# Collecting museval (from uvr==0.1)
#   Using cached museval-0.4.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting mypy (from uvr==0.1)
#   Using cached mypy-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Collecting openunmix (from uvr==0.1)
#   Using cached openunmix-1.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from uvr==0.1) (6.0.3)
# Collecting submitit (from uvr==0.1)
#   Using cached submitit-1.5.4-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from uvr==0.1) (4.67.1)
# Collecting treetable (from uvr==0.1)
#   Using cached treetable-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from uvr==0.1) (8.4.2)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from uvr==0.1) (0.11.0)
# Collecting audiofile (from uvr==0.1)
#   Using cached audiofile-1.6.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.12/dist-packages (from uvr==0.1) (1.23.2)
# Collecting onnx (from uvr==0.1)
#   Using cached onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Collecting onnx2pytorch (from uvr==0.1)
#   Using cached onnx2pytorch-0.5.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting ml_collections (from uvr==0.1)
#   Using cached ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from uvr==0.1) (0.13.1)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dora-search>=0.1.12->uvr==0.1) (2.3.0)
# Collecting retrying (from dora-search>=0.1.12->uvr==0.1)
#   Using cached retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from dora-search>=0.1.12->uvr==0.1) (2.9.0+cu126)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from hydra-colorlog>=1.1->uvr==0.1) (6.10.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.1->uvr==0.1) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.1->uvr==0.1) (25.0)
# Collecting audeer (from audiofile->uvr==0.1)
#   Using cached audeer-2.3.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting audmath>=1.3.0 (from audiofile->uvr==0.1)
#   Using cached audmath-1.4.4-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Building wheel for uvr (setup.py) ... done
#   Created wheel for uvr: filename=uvr-0.1-py3-none-any.whl size=254857 sha256=82aca047f3e5e94672ea4fb7994341a41efe94e8816d383c16473bed4e315456
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e2yaz91x/wheels/f4/ae/6d/ae4aa101ce22cd60ea6fb6da70aba132fee52f6fe7c4208f2b
# Successfully built uvr
# Installing collected packages: lameenc, treetable, submitit, retrying, pyflakes, pycodestyle, pyaml, pathspec, numpy, mypy_extensions, ml_collections, mccabe, librt, ffmpeg-python, audeer, stempeg, mypy, hydra-core, flake8, audmath, onnx, musdb, hydra-colorlog, audiofile, museval, dora-search, openunmix, onnx2pytorch, uvr
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.1
#     Uninstalling numpy-2.4.1:
#       Successfully uninstalled numpy-2.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyannote-metrics 4.0.0 requires numpy>=2.2.2, but you have numpy 2.0.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed audeer-2.3.1 audiofile-1.6.0 audmath-1.4.4 dora-search-0.1.12 ffmpeg-python-0.2.0 flake8-7.3.0 hydra-colorlog-1.2.0 hydra-core-1.3.2 lameenc-1.8.1 librt-0.7.8 mccabe-0.7.0 ml_collections-1.1.0 musdb-0.4.3 museval-0.4.1 mypy-1.19.1 mypy_extensions-1.1.0 numpy-2.0.2 onnx-1.20.1 onnx2pytorch-0.5.3 openunmix-1.3.0 pathspec-1.0.3 pyaml-25.7.0 pycodestyle-2.14.0 pyflakes-3.4.0 retrying-1.4.2 stempeg-0.2.6 submitit-1.5.4 treetable-0.2.6 uvr-0.1
# Collecting git+https://github.com/jhj0517/gradio-i18n.git
#   Cloning https://github.com/jhj0517/gradio-i18n.git to /tmp/pip-req-build-xxcsmgx5
#   Running command git clone --filter=blob:none --quiet https://github.com/jhj0517/gradio-i18n.git /tmp/pip-req-build-xxcsmgx5
#   Resolved https://github.com/jhj0517/gradio-i18n.git to commit 823ee4d31b3a54d610a8e35e26ff414fabc715f5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gradio>=4.32 in /usr/local/lib/python3.12/dist-packages (from gradio-i18n==0.3.1) (5.29.0)
# Requirement already satisfied: langcodes<3.5 in /usr/local/lib/python3.12/dist-packages (from gradio-i18n==0.3.1) (3.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from gradio-i18n==0.3.1) (6.0.3)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (4.12.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.123.10)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (1.0.0)
# Requirement already satisfied: gradio-client==1.10.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (1.10.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (3.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (2.3.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (2.11.10)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.0.21)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.14.13)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.21.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.32->gradio-i18n==0.3.1) (0.40.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.10.0->gradio>=4.32->gradio-i18n==0.3.1) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.10.0->gradio>=4.32->gradio-i18n==0.3.1) (15.0.1)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<3.5->gradio-i18n==0.3.1) (1.4.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio>=4.32->gradio-i18n==0.3.1) (3.11)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio>=4.32->gradio-i18n==0.3.1) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio>=4.32->gradio-i18n==0.3.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio>=4.32->gradio-i18n==0.3.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=4.32->gradio-i18n==0.3.1) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (1.2.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<3.5->gradio-i18n==0.3.1) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.32->gradio-i18n==0.3.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.32->gradio-i18n==0.3.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.32->gradio-i18n==0.3.1) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio>=4.32->gradio-i18n==0.3.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio>=4.32->gradio-i18n==0.3.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio>=4.32->gradio-i18n==0.3.1) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio>=4.32->gradio-i18n==0.3.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.28.1->gradio>=4.32->gradio-i18n==0.3.1) (2.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.32->gradio-i18n==0.3.1) (0.1.2)
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Collecting torch==2.8.0
#   Downloading https://download.pytorch.org/whl/cu126/torch-2.8.0%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchvision==0.23.0
#   Downloading https://download.pytorch.org/whl/cu126/torchvision-0.23.0%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio==2.8.0
#   Downloading https://download.pytorch.org/whl/cu126/torchaudio-2.8.0%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (0.7.1)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch==2.8.0)
#   Downloading https://pypi.nvidia.com/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 85.9 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (1.11.1.6)
# Collecting triton==3.4.0 (from torch==2.8.0)
#   Downloading https://download.pytorch.org/whl/triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.23.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.23.0) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0) (3.0.3)
# Downloading https://download.pytorch.org/whl/cu126/torch-2.8.0%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl (821.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.8/821.8 MB 1.0 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/torchvision-0.23.0%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 61.4 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/torchaudio-2.8.0%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 51.5 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nccl-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.5.0
#     Uninstalling triton-3.5.0:
#       Successfully uninstalled triton-3.5.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:

# %%
#@title # (Optional) Mount Google Drive
#@markdown Uploading large input files directly via UI may consume alot of time because it has to be uploaded in colab's server.
#@markdown <br>This section is for using the input file paths from Google Drive to reduce such file uploading time.
#@markdown <br>For example, you can first upload the input file to Google Drive and use the directroy path in the "Input Folder Path" input, as shown below.

#@markdown ![image](https://github.com/user-attachments/assets/85330905-e3ec-4502-bc4b-b9d1c5b41aa2)

#@markdown <br>And it will mount the output paths to your Google Drive's as well. This section is optional and can be ignored.


# Mount Google Drive
from google.colab import drive
import os
drive.mount('/content/drive')


# Symlink Output Paths for Whisper-WebUI
import os

OUTPUT_DIRECTORY_PATH = '/content/drive/MyDrive/Whisper-WebUI/outputs'  # @param {type:"string"}
local_output_path = '/content/Whisper-WebUI/outputs'
os.makedirs(local_output_path, exist_ok=True)
os.makedirs(OUTPUT_DIRECTORY_PATH, exist_ok=True)

if os.path.exists(local_output_path):
    # !rm -r "$local_output_path"

os.symlink(OUTPUT_DIRECTORY_PATH, local_output_path)
# !ls "$local_output_path"

# %%
#@title # (Optional) Configure arguments
#@markdown This section is used to configure some command line arguments.

#@markdown You can simply ignore this section and the default values will be used.

USERNAME = '' #@param {type: "string"}
PASSWORD = '' #@param {type: "string"}
WHISPER_TYPE = 'faster-whisper' # @param ["whisper", "faster-whisper", "insanely_fast_whisper"]
THEME = '' #@param {type: "string"}

arguments = ""
if USERNAME:
  arguments += f" --username {USERNAME}"
if PASSWORD:
  arguments += f" --password {PASSWORD}"
if THEME:
  arguments += f" --theme {THEME}"
if WHISPER_TYPE:
  arguments += f" --whisper_type {WHISPER_TYPE}"


#@markdown If you wonder how these arguments are used, you can see the [Wiki](https://github.com/jhj0517/Whisper-WebUI/wiki/Command-Line-Arguments).

# %%
#@title #Run
#@markdown Once the installation is complete, you can use public URL that is displayed.
if 'arguments' in locals():
  # !python app.py --share --colab --allowed_path "['/content/Whisper-WebUI/outputs']"{arguments}
else:
    # !python app.py --share --colab --allowed_path "['/content/Whisper-WebUI/outputs']"
